# %%
from stl import mesh
from mpl_toolkits import mplot3d
from matplotlib import pyplot

# %%
STLFiles=["Needle_4cm.stl","Needle_9cm.stl","Needle_14cm.stl"]

needle=mesh.Mesh.from_file(STL)

# %%
# Create a new plot
figure = pyplot.figure(figsize=(15,15))
axes = figure.add_subplot(projection='3d')
percent=0.85
pointPercent=round(len(needle.vectors)*percent)
axes.add_collection3d(mplot3d.art3d.Poly3DCollection(needle.vectors[pointPercent:len(needle.vectors)]))
# Auto scale to the mesh size
scale = needle.points.flatten()
axes.auto_scale_xyz(scale, scale, scale)

# Show the plot to the screen
pyplot.show()
print(needle.vectors[pointPercent:len(needle.vectors)])
# Out:
# [[[ 5.608889  5.122139 39.30042 ]
#   [ 5.752794  5.312427 39.3501  ]
#   [ 5.767457  5.29556  39.29232 ]]
#
#  [[ 5.608889  5.122139 39.30042 ]
#   [ 5.767457  5.29556  39.29232 ]
#   [ 5.621285  5.133419 39.29232 ]]
#
#  [[ 5.621285  5.133419 39.29232 ]
#   [ 5.567717  5.044002 39.29232 ]
#   [ 5.608889  5.122139 39.30042 ]]
#
#  ...
#
#  [[ 5.743869  4.800801 39.29232 ]
#   [ 5.7493    4.791252 39.65232 ]
#   [ 5.7493    4.791252 39.29232 ]]
#
#  [[ 5.7493    4.791252 39.29232 ]
#   [ 5.7493    4.791252 39.65232 ]
#   [ 5.755837  4.782631 39.65232 ]]
#
#  [[ 5.7493    4.791252 39.29232 ]
#   [ 5.755837  4.782631 39.65232 ]
#   [ 5.755837  4.782631 39.29232 ]]]
